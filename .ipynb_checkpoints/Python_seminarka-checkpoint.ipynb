# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sales = pd.read_csv("videogames_sales.csv")
sales.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
sales.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000     60.000000     12.000000     10.000000
# 50%        0.010000      0.170000     71.000000     21.000000     24.000000
# 75%        0.030000      0.470000     79.000000     36.000000     81.000000
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %%
#sales.isnull.sum()

# %%
#sales['Year'] = sales['Year_of_Release'].astype(int)

# %%
plt.figure(figsize=(40,20))
sns.set(font_scale = 3)
sns.heatmap(sales.isnull(),yticklabels=False,cbar=False,cmap='magma')

# %%
plt.figure(figsize=(40,50))
sns.set(font_scale = 1)
sns.jointplot(x="Year_of_Release", y="NA_Sales", data=sales)
# Out:
# C:\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sales = sales.dropna()

# %%
plt.figure(figsize=(40,20))
sns.set(font_scale = 3)
sns.heatmap(sales.isnull(),yticklabels=False,cbar=False,cmap='magma')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 16 columns):
# Name               6825 non-null object
# Platform           6825 non-null object
# Year_of_Release    6825 non-null float64
# Genre              6825 non-null object
# Publisher          6825 non-null object
# NA_Sales           6825 non-null float64
# EU_Sales           6825 non-null float64
# JP_Sales           6825 non-null float64
# Other_Sales        6825 non-null float64
# Global_Sales       6825 non-null float64
# Critic_Score       6825 non-null float64
# Critic_Count       6825 non-null float64
# User_Score         6825 non-null object
# User_Count         6825 non-null float64
# Developer          6825 non-null object
# Rating             6825 non-null object
# dtypes: float64(9), object(7)
# memory usage: 906.4+ KB

# %%
plt.figure(figsize=(40,20))
sns.set(font_scale = 3)
sns.countplot(x='Genre', data=sales, order = sales['Genre'].value_counts().index, palette="magma")

# %%
sales['Year_of_Release'] = sales['Year_of_Release'].astype(int)
plt.figure(figsize=(40,20))
sns.set(font_scale = 3)
sns.countplot(x='Year_of_Release', data=sales, order = sales['Year_of_Release'].value_counts().index, palette="magma")

# %%
plt.figure(figsize=(40,20))
sns.set(font_scale = 3)
sns.countplot(x='Rating', data=sales, order = sales['Rating'].value_counts().index, palette="magma")

# %%
# plt.figure(figsize=(40,20))
# # sns.set(font_scale = 3)
# # sns.countplot(x='Publisher', data=sales, order = sales['Publisher'].value_counts().index, palette="magma")
# ax = sns.barplot(x=sales['Publisher'], y=sales['Publisher'].value_counts(), data=sales, estimator=lambda x: len(x) / len(sales) * 100)

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale = 2)
sns.heatmap(sales.corr())

# %%
# plt.figure(figsize=(50,30))
# sns.countplot(x='Developer',data=sales)
# plt.xticks(rotation=90)

# %%
sales.groupby('Developer').nunique()
# Out:
#                                        Name  Platform  Year_of_Release  Genre  \
# Developer
# 10tacle Studios, Fusionsphere Systems     1         2                1      1
# 1C, 1C Company                            2         1                2      1
# 1C, Ino-Co, 1C Company                    1         1                1      1
# 1C: Maddox Games                          2         1                2      1
# 1C:Ino-Co                                 1         1                1      1
# 1st Playable Productions                  2         1                1      2
# 2015                                      1         1                1      1
# 2D Boy                                    1         1                1      1
# 2K Australia                              1         3                1      1
# 2K Czech                                  2         3                2      2
# 2K Games                                  2         3                2      2
# 2K Marin                                  2         3                2      1
# 2K Sports                                 6         5                4      2
# 2XL Games                                 1         2                1      1
# 343 Industries                            4         2                4      1
# 369 Interactive                           1         1                1      1
# 3DO                                      14         4                5      5
# 3G Studios                                2         2                2      2
# 3d6 Games                                 1         1                1      1
# 49Games                                   2         2                2      1
# 4A Games                                  2         2                2      2
# 4J Studios                                4         3                2      4
# 5000ft                                    1         1                1      1
# 505 Games                                 2         2                2      2
# 5TH Cell                                  7         3                6      3
# 5pb                                       5         3                5      1
# 7 Studios                                 7         6                5      4
# 8Monkey Labs                              1         1                1      1
# 8ing/Raizing                              3         2                3      1
# 989 Sports                               12         3                5      1
# ...                                     ...       ...              ...    ...
# Xpec                                      5         6                4      3
# Yacht Club Games                          1         3                1      1
# Yager                                     2         4                2      1
# Yuke's                                   22         9               15      4
# Z-Axis, Ltd.                              7         6                5      3
# Zed Two Limited                           1         1                1      1
# Zed Two Limited                                   1             1           1
# Zen Studios                                       1             1           1
# Zener Works                                       1             1           1
# ZeniMax Media                                     2             2           2
# Zerodiv                                           3             3           3
# Zindagi Games                                     1             1           1
# Zipper Interactive                                6             7           6
# Zoe Mode                                          8             7           7
# Zoe Mode, HB Studios Multimedia                   1             1           1
# Zombie                                            1             1           1
# Zombie Studios                                    3             4           4
# Zono Inc.                                         2             2           2
# Zoo Games                                         1             1           1
# Zoom                                              1             1           1
# ZootFly                                           2             2           2
# h.a.n.d. Inc.                                     5             6           6
# iNiS                                              4             4           4
# id Software                                       6             8           8
# id Software, Nerve Software                       1             1           1
# id Software, Raven Software                       3             3           3
# n-Space                                          11             9          12
# neo Software                                      1             1           1
# odenis studio                                     1             1           1
# syn Sophia                                        2             2           2
# zSlide                                            1             1           1
#
#                                        User_Count  Developer  Rating
# Developer
# 10tacle Studios, Fusionsphere Systems           2          1       1
# 1C, 1C Company                                  2          1       1
# 1C, Ino-Co, 1C Company                          1          1       1
# 1C: Maddox Games                                2          1       1
# 1C:Ino-Co                                       1          1       1
# 1st Playable Productions                        2          1       2
# 2015                                            1          1       1
# 2D Boy                                          1          1       1
# 2K Australia                                    3          1       1
# 2K Czech                                        5          1       2
# 2K Games                                        3          1       2
# 2K Marin                                        5          1       1
# 2K Sports                                      10          1       3
# 2XL Games                                       2          1       1
# 343 Industries                                  4          1       2
# 369 Interactive                                 1          1       1
# 3DO                                             8          1       2
# 3G Studios                                      2          1       2
# 3d6 Games                                       1          1       1
# 49Games                                         1          1       1
# 4A Games                                        3          1       1
# 4J Studios                                      4          1       3
# 5000ft                                          1          1       1
# 505 Games                                       2          1       1
# 5TH Cell                                        9          1       2
# 5pb                                             7          1       2
# 7 Studios                                       8          1       3
# 8Monkey Labs                                    1          1       1
# 8ing/Raizing                                    3          1       1
# 989 Sports                                      7          1       1
# ...                                           ...        ...     ...
# Xpec                                            5          1       3
# Yacht Club Games                                3          1       1
# Yager                                           4          1       2
# Yuke's                                         38          1       3
# Z-Axis, Ltd.                                    9          1       3
# Zed Two Limited                                 1          1       1
# Zen Studios                                     1          1       1
# Zener Works                                     1          1       1
# ZeniMax Media                                   2          1       1
# Zerodiv                                         3          1       1
# Zindagi Games                                   1          1       1
# Zipper Interactive                              8          1       2
# Zoe Mode                                        6          1       2
# Zoe Mode, HB Studios Multimedia                 1          1       1
# Zombie                                          1          1       1
# Zombie Studios                                  4          1       2
# Zono Inc.                                       2          1       1
# Zoo Games                                       1          1       1
# Zoom                                            1          1       1
# ZootFly                                         2          1       1
# h.a.n.d. Inc.                                   6          1       3
# iNiS                                            4          1       2
# id Software                                     8          1       1
# id Software, Nerve Software                     1          1       1
# id Software, Raven Software                     3          1       1
# n-Space                                        11          1       4
# neo Software                                    1          1       1
# odenis studio                                   1          1       1
# syn Sophia                                      2          1       1
# zSlide                                          1          1       1
#
# [1289 rows x 16 columns]

# %%
# sales['NA_Sales_quantile'] = pd.qcut(sales['NA_Sales'], 5, labels=["very_low", "low", "medium", "high", "very_high"])

# %%
# sales.head(350)

# %%
def createDummies(column, prefix):
    column_quantiles = pd.qcut(sales[column].rank(method='first'), 5, labels=["very_low", "low", "medium", "high", "very_high"], duplicates='raise')
    dummies = pd.get_dummies(column_quantiles, prefix=prefix)
    return dummies

# %%
# na_sales_dummies = createDummies('NA_Sales', 'na_sales_')
# eu_sales_dummies = createDummies('EU_Sales', 'eu_sales_')
# jp_sales_dummies = createDummies('JP_Sales', 'jp_sales_')
# other_sales_dummies = createDummies('Other_Sales', 'other_sales_')
# global_sales_dummies = createDummies('Global_Sales', 'global_sales_')
critic_score_dummies = createDummies('Critic_Score', 'critic_score_')
critic_count_dummies = createDummies('Critic_Count', 'critic_count_')
# user_score_dummies = createDummies('User_Score', 'user_score_')
user_count_dummies = createDummies('User_Count', 'user_count_')
sales = pd.concat([sales, critic_score_dummies, critic_count_dummies, user_count_dummies], axis=1)
# sales = pd.concat([sales, na_sales_dummies,eu_sales_dummies,jp_sales_dummies, other_sales_dummies, global_sales_dummies], axis=1)
sales = sales.drop(['Critic_Score', 'Critic_Count', 'User_Count'], axis=1)
# sales = sales.drop(['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'], axis=1)

# %%
sales.head()
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii             2006    Sports  Nintendo
# 2         Mario Kart Wii      Wii             2008    Racing  Nintendo
# 3      Wii Sports Resort      Wii             2009    Sports  Nintendo
# 6  New Super Mario Bros.       DS             2006  Platform  Nintendo
# 7               Wii Play      Wii             2006      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0     41.36     28.96      3.77         8.45         82.53
# 2     15.68     12.76      3.79         3.29         35.52
# 3     15.61     10.93      3.28         2.95         32.77
# 6     11.28      9.14      6.50         2.88         29.80
# 7     13.96      9.18      2.93         2.84         28.92
#
#            ...           critic_count__very_low critic_count__low  \
# 0          ...                                0                 0
# 2          ...                                0                 0
# 3          ...                                0                 0
# 6          ...                                0                 0
# 7          ...                                0                 0
#
#   critic_count__medium  critic_count__high  critic_count__very_high  \
# 0                    0                   0                        1
# 2                    0                   0                        1
# 3                    0                   0                        1
# 6                    0                   0                        1
# 7                    0                   1                        0
#
#    user_count__very_low  user_count__low  user_count__medium  \
# 0                     0                0                   0
# 2                     0                0                   0
# 3                     0                0                   0
# 6                     0                0                   0
# 7                     0                0                   0
#
#    user_count__high  user_count__very_high
# 0                 0                      1
# 2                 0                      1
# 3                 0                      1
# 6                 0                      1
# 7                 0                      1
#
# [5 rows x 28 columns]

# %%
# sales.info()

# %%
sales['Rating'].unique()
# Out:
# array(['E', 'M', 'T', 'E10+', 'AO', 'K-A', 'RP'], dtype=object)

# %%
sales['Rating'].replace('E10+', 'E10plus',inplace=True)
sales['Rating'].replace('K-A', 'KA',inplace=True)
sales['Rating'] = sales['Rating'].str.lower()

# %%
sales['Rating'].unique()
# Out:
# array(['e', 'm', 't', 'e10plus', 'ao', 'ka', 'rp'], dtype=object)

# %%
dummies = pd.get_dummies(sales['Rating'], prefix='rating_')
sales = pd.concat([sales, dummies], axis=1)
sales = sales.drop(['Rating'], axis=1)

# %%
# sales.info()

# %%
sales['Developer'].nunique()
# Out:
# 1289

# %%
sales['Genre'].nunique()
# Out:
# 12

# %%
sales['Genre'].unique()
# Out:
# array(['Sports', 'Racing', 'Platform', 'Misc', 'Action', 'Puzzle',
#        'Shooter', 'Fighting', 'Simulation', 'Role-Playing', 'Adventure',
#        'Strategy'], dtype=object)

# %%
sales['Genre'] = sales['Genre'].str.lower()
dummies = pd.get_dummies(sales['Genre'], prefix='genre_')
sales = pd.concat([sales, dummies], axis=1)
sales = sales.drop(['Genre'], axis=1)
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 45 columns):
# Name                       6825 non-null object
# Platform                   6825 non-null object
# Year_of_Release            6825 non-null int32
# Publisher                  6825 non-null object
# NA_Sales                   6825 non-null float64
# EU_Sales                   6825 non-null float64
# JP_Sales                   6825 non-null float64
# Other_Sales                6825 non-null float64
# Global_Sales               6825 non-null float64
# User_Score                 6825 non-null object
# Developer                  6825 non-null object
# critic_score__very_low     6825 non-null uint8
# critic_score__low          6825 non-null uint8
# critic_score__medium       6825 non-null uint8
# critic_score__high         6825 non-null uint8
# critic_score__very_high    6825 non-null uint8
# critic_count__very_low     6825 non-null uint8
# critic_count__low          6825 non-null uint8
# critic_count__medium       6825 non-null uint8
# critic_count__high         6825 non-null uint8
# critic_count__very_high    6825 non-null uint8
# user_count__very_low       6825 non-null uint8
# user_count__low            6825 non-null uint8
# user_count__medium         6825 non-null uint8
# user_count__high           6825 non-null uint8
# user_count__very_high      6825 non-null uint8
# rating__ao                 6825 non-null uint8
# rating__e                  6825 non-null uint8
# rating__e10plus            6825 non-null uint8
# rating__ka                 6825 non-null uint8
# rating__m                  6825 non-null uint8
# rating__rp                 6825 non-null uint8
# rating__t                  6825 non-null uint8
# genre__action              6825 non-null uint8
# genre__adventure           6825 non-null uint8
# genre__fighting            6825 non-null uint8
# genre__misc                6825 non-null uint8
# genre__platform            6825 non-null uint8
# genre__puzzle              6825 non-null uint8
# genre__racing              6825 non-null uint8
# genre__role-playing        6825 non-null uint8
# genre__shooter             6825 non-null uint8
# genre__simulation          6825 non-null uint8
# genre__sports              6825 non-null uint8
# genre__strategy            6825 non-null uint8
# dtypes: float64(5), int32(1), object(5), uint8(34)
# memory usage: 1.1+ MB

# %%
sales['Year_of_Release'].nunique()
# Out:
# 25

# %%
sales['Publisher'].nunique()
# Out:
# 262

# %%
train = sales.drop(['Name', 'User_Score', 'Developer', 'Platform','Year_of_Release','Publisher', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],axis=1)
train['NA_Sales'] = train['NA_Sales'].astype(int)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6825 entries, 0 to 16706
# Data columns (total 35 columns):
# NA_Sales                   6825 non-null int32
# critic_score__very_low     6825 non-null uint8
# critic_score__low          6825 non-null uint8
# critic_score__medium       6825 non-null uint8
# critic_score__high         6825 non-null uint8
# critic_score__very_high    6825 non-null uint8
# critic_count__very_low     6825 non-null uint8
# critic_count__low          6825 non-null uint8
# critic_count__medium       6825 non-null uint8
# critic_count__high         6825 non-null uint8
# critic_count__very_high    6825 non-null uint8
# user_count__very_low       6825 non-null uint8
# user_count__low            6825 non-null uint8
# user_count__medium         6825 non-null uint8
# user_count__high           6825 non-null uint8
# user_count__very_high      6825 non-null uint8
# rating__ao                 6825 non-null uint8
# rating__e                  6825 non-null uint8
# rating__e10plus            6825 non-null uint8
# rating__ka                 6825 non-null uint8
# rating__m                  6825 non-null uint8
# rating__rp                 6825 non-null uint8
# rating__t                  6825 non-null uint8
# genre__action              6825 non-null uint8
# genre__adventure           6825 non-null uint8
# genre__fighting            6825 non-null uint8
# genre__misc                6825 non-null uint8
# genre__platform            6825 non-null uint8
# genre__puzzle              6825 non-null uint8
# genre__racing              6825 non-null uint8
# genre__role-playing        6825 non-null uint8
# genre__shooter             6825 non-null uint8
# genre__simulation          6825 non-null uint8
# genre__sports              6825 non-null uint8
# genre__strategy            6825 non-null uint8
# dtypes: int32(1), uint8(34)
# memory usage: 626.6 KB

# %%
columns = list(train)
columns.remove('NA_Sales')
columns
# Out:
# ['critic_score__very_low',
#  'critic_score__low',
#  'critic_score__medium',
#  'critic_score__high',
#  'critic_score__very_high',
#  'critic_count__very_low',
#  'critic_count__low',
#  'critic_count__medium',
#  'critic_count__high',
#  'critic_count__very_high',
#  'user_count__very_low',
#  'user_count__low',
#  'user_count__medium',
#  'user_count__high',
#  'user_count__very_high',
#  'rating__ao',
#  'rating__e',
#  'rating__e10plus',
#  'rating__ka',
#  'rating__m',
#  'rating__rp',
#  'rating__t',
#  'genre__action',
#  'genre__adventure',
#  'genre__fighting',
#  'genre__misc',
#  'genre__platform',
#  'genre__puzzle',
#  'genre__racing',
#  'genre__role-playing',
#  'genre__shooter',
#  'genre__simulation',
#  'genre__sports',
#  'genre__strategy']

# %%
X = sales[columns]
y = sales['NA_Sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lm.intercept_)
# Out:
# 759457567702.1094

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                           Coefficient
# critic_score__very_low  -2.337967e+11
# critic_score__low       -2.337967e+11
# critic_score__medium    -2.337967e+11
# critic_score__high      -2.337967e+11
# critic_score__very_high -2.337967e+11
# critic_count__very_low  -3.079573e+12
# critic_count__low       -3.079573e+12
# critic_count__medium    -3.079573e+12
# critic_count__high      -3.079573e+12
# critic_count__very_high -3.079573e+12
# user_count__very_low    -4.171186e+12
# user_count__low         -4.171186e+12
# user_count__medium      -4.171186e+12
# user_count__high        -4.171186e+12
# user_count__very_high   -4.171186e+12
# rating__ao               4.666150e+12
# rating__e                5.212950e+12
# rating__e10plus          5.212950e+12
# rating__ka              -7.721702e+12
# rating__m                5.212950e+12
# rating__rp               5.212950e+12
# rating__t                5.212950e+12
# genre__action            1.512148e+12
# genre__adventure         1.512148e+12
# genre__fighting          1.512148e+12
# genre__misc              1.512148e+12
# genre__platform          1.512148e+12
# genre__puzzle            1.512148e+12
# genre__racing            1.512148e+12
# genre__role-playing      1.512148e+12
# genre__shooter           1.512148e+12
# genre__simulation        1.512148e+12
# genre__sports            1.512148e+12
# genre__strategy          1.512148e+12

# %%
predictions = lm.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 4938261028.305843
# MSE: 6.13934901542042e+22
# RMSE: 247777097719.3094

# %%
#Randomforest
from sklearn.ensemble import RandomForestClassifier
sales = pd.read_csv("videogames_sales.csv")
sales = sales.dropna()
sales.head()
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 6          65.0        8.5       431.0  Nintendo      E
# 7          41.0        6.6       129.0  Nintendo      E

# %%
sales = sales.drop(['Name', 'User_Score', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'NA_Sales','Rating'],axis=1)

sales['Platform'] = pd.factorize(sales['Platform'])[0]
sales['Genre'] = pd.factorize(sales['Genre'])[0]
sales['Publisher'] = pd.factorize(sales['Publisher'])[0]
sales['Developer'] = pd.factorize(sales['Developer'])[0]
sales['Global_Sales'] = pd.qcut(sales['Global_Sales'].rank(method='max'), 5, labels=["very_low","low", "average", "high", "very_high"])

# %%
columns = list(sales)
columns.remove('Global_Sales')
columns

X = sales[columns]
y = sales['Global_Sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
clf = RandomForestClassifier(n_jobs=2, random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=2,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y_predict = clf.predict(X_test)

# %%
clf.predict_proba(X_test)[0:10]
# Out:
# array([[0.4, 0. , 0.6, 0. , 0. ],
#        [0.1, 0.2, 0. , 0.3, 0.4],
#        [0.5, 0.1, 0.4, 0. , 0. ],
#        [0. , 0. , 0. , 0. , 1. ],
#        [0.2, 0.2, 0.3, 0. , 0.3],
#        [0. , 0. , 0.1, 0. , 0.9],
#        [0.3, 0. , 0.1, 0. , 0.6],
#        [0.4, 0.2, 0.1, 0.1, 0.2],
#        [0.1, 0.8, 0. , 0.1, 0. ],
#        [0.2, 0.4, 0.3, 0.1, 0. ]])

# %%
list(zip(X_train, clf.feature_importances_))
# Out:
# [('Platform', 0.09113547869854002),
#  ('Year_of_Release', 0.0983721825058769),
#  ('Genre', 0.07607507173072364),
#  ('Publisher', 0.12082969479608272),
#  ('Critic_Score', 0.12333452718141791),
#  ('Critic_Count', 0.12550469012187296),
#  ('User_Count', 0.15547518970631985),
#  ('Developer', 0.20927316525916603)]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_predict)
# Out:
# array([[212, 123, 104,  42,  44],
#        [134, 237,  47,  98,  21],
#        [152,  76, 192,  11, 111],
#        [ 53, 106,  17, 367,  15],
#        [ 87,  50, 127,  14, 290]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predict))
# Out:
#              precision    recall  f1-score   support
#
#     average       0.33      0.40      0.36       525
#        high       0.40      0.44      0.42       537
#         low       0.39      0.35      0.37       542
#   very_high       0.69      0.66      0.67       558
#    very_low       0.60      0.51      0.55       568
#
# avg / total       0.49      0.48      0.48      2730
